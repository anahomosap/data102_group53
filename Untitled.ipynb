# %%
import pandas as pd
import numpy as np

# %%
health = pd.read_csv('county_health_data.csv', usecols = ['5-digit FIPS Code', 'Name', 'Adult obesity raw value', 'Adult smoking raw value', 'Physical inactivity raw value', 'Excessive drinking raw value', 'Median household income raw value', 'Uninsured raw value'])
# Out:
# /tmp/ipykernel_276/599848541.py:1: DtypeWarning: Columns (2,69,74,84,94,129,507) have mixed types. Specify dtype option on import or set low_memory=False.
#   health = pd.read_csv('county_health_data.csv', usecols = ['5-digit FIPS Code', 'Name', 'Adult obesity raw value', 'Adult smoking raw value', 'Physical inactivity raw value', 'Excessive drinking raw value', 'Median household income raw value', 'Uninsured raw value'])

# %%
health
# Out:
#      5-digit FIPS Code               Name Adult smoking raw value  \
# 0             fipscode             county           v009_rawvalue
# 1                00000      United States             0.166224667
# 2                01000            Alabama              0.19989831
# 3                01001     Autauga County             0.198107659
# 4                01003     Baldwin County             0.185133183
# ...                ...                ...                     ...
# 3190             56037  Sweetwater County                0.185086
# 3191             56039       Teton County                0.128844
# 3192             56041       Uinta County                0.207645
# 3193             56043    Washakie County                0.194425
# 3194             56045      Weston County                0.206386
#
#      Adult obesity raw value Physical inactivity raw value  \
# 0              v011_rawvalue                 v070_rawvalue
# ...

# %%
pd.read_csv('test.csv')
